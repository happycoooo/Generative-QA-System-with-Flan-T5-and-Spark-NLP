# %%
from config import *
import datasets
from transformers import T5ForConditionalGeneration, T5Tokenizer, Seq2SeqTrainer, Seq2SeqTrainingArguments
import ray
from ray.train.huggingface.transformers import (
    RayTrainReportCallback,
    prepare_trainer,
)
from ray.train import ScalingConfig
from ray.train.torch import TorchTrainer
from ray import tune
from ray.tune.search.optuna import OptunaSearch

# %%
dataset = datasets.load_from_disk("/data/lab/assignments/proj2/project2/Task1/squad_v2_tokenized_datasets")
dataset = dataset.train_test_split(test_size=test_size)

ray_train_ds = ray.data.from_huggingface(dataset["train"])
ray_eval_ds = ray.data.from_huggingface(dataset["test"])

max_steps_per_epoch = ray_train_ds.count() // (batch_size * num_workers)

# %%
import os
# 指定checkpoint目录
checkpoint_dir = "/root/ray_results/TorchTrainer_2024-05-29_07-12-59/TorchTrainer_e1617_00000_0_2024-05-29_07-12-59/checkpoint_000000/checkpoint"

# 确认 checkpoint 目录存在
if os.path.exists(checkpoint_dir):
    # 加载模型和分词器
    model = T5ForConditionalGeneration.from_pretrained(checkpoint_dir)
    tokenizer = T5Tokenizer.from_pretrained(checkpoint_dir)
    print("Model and tokenizer loaded from checkpoint:", checkpoint_dir)
else:
    raise FileNotFoundError("Checkpoint directory not found: {}".format(checkpoint_dir))
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Model and tokenizer loaded from checkpoint: /root/ray_results/TorchTrainer_2024-05-29_07-12-59/TorchTrainer_e1617_00000_0_2024-05-29_07-12-59/checkpoint_000000/checkpoint

# %%
def train_func(config):
    model = T5ForConditionalGeneration.from_pretrained(model_dir)
    tokenizer = T5Tokenizer.from_pretrained(model_dir)
    
    dataset = datasets.load_from_disk("/data/lab/assignments/proj2/project2/Task1/squad_v2_tokenized_datasets")
    dataset = dataset.train_test_split(test_size=test_size)
    
    training_args = Seq2SeqTrainingArguments(
        per_device_train_batch_size=batch_size,
        overwrite_output_dir=True,
        save_total_limit=save_total_limit,
        logging_dir="./logs",
        num_train_epochs=num_train_epochs,
        report_to="none",
        per_device_eval_batch_size=batch_size,
        save_strategy="steps",
        max_steps=20,
        evaluation_strategy="steps",
        output_dir="./checkpoints",
        warmup_steps=2*eval_steps,
        learning_rate=learning_rate,
        logging_steps=eval_steps,
        predict_with_generate=True,
        gradient_accumulation_steps=gradient_accumulation_steps,
        save_steps=eval_steps,
        eval_steps=eval_steps,
    )
   
    trainer = Seq2SeqTrainer(
        model=model,
        tokenizer=tokenizer,
        args=training_args,
        train_dataset=dataset["train"],
        eval_dataset=dataset["test"],
    )
    
    trainer.add_callback(RayTrainReportCallback())
    trainer = prepare_trainer(trainer)
    trainer.train()
    
    return {"eval_loss": trainer.state.log_history[1]['eval_loss']}

# %%
tuner = tune.Tuner(
    train_func,
    tune_config=tune.TuneConfig(
        metric="eval_loss",
        mode="min",
    ),
    param_space=search_space,
)
results = tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-05-29 19:35:09</td></tr>
# <tr><td>Running for: </td><td>03:31:50.69        </td></tr>
# <tr><td>Memory:      </td><td>598.9/1007.4 GiB   </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/128 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name            </th><th>status    </th><th>loc               </th><th style="text-align: right;">    lr</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>train_func_f74df_00000</td><td>TERMINATED</td><td>172.17.0.38:487477</td><td style="text-align: right;">0.0001</td><td style="text-align: right;">    11</td><td style="text-align: right;">         12706.6</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# (train_func pid=487477) You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# (train_func pid=487477) Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# (train_func pid=487477) /root/anaconda3/envs/sp/lib/python3.11/site-packages/transformers/training_args.py:1474: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
# (train_func pid=487477)   warnings.warn(
# (train_func pid=487477) max_steps is given, it will override any value given in num_train_epochs
#   0%|          | 0/20 [00:00<?, ?it/s]
#   5%|▌         | 1/20 [02:42<51:33, 162.82s/it]
# (train_func pid=487477) {'loss': 1.1286, 'grad_norm': 3.6692216396331787, 'learning_rate': 5e-05, 'epoch': 0.0}
#  10%|█         | 2/20 [05:16<47:12, 157.36s/it]
# (train_func pid=487477)
#   0%|          | 0/163 [00:00<?, ?it/s]
# (train_func pid=487477)
#   1%|          | 2/163 [00:05<07:41,  2.87s/it]
# (train_func pid=487477)
#   2%|▏         | 3/163 [00:11<10:46,  4.04s/it]
# (train_func pid=487477)
#   2%|▏         | 4/163 [00:17<12:20,  4.66s/it]
# (train_func pid=487477)
#   3%|▎         | 5/163 [00:22<13:13,  5.02s/it]
# (train_func pid=487477)
#   4%|▎         | 6/163 [00:28<13:43,  5.24s/it]
# (train_func pid=487477)
#   4%|▍         | 7/163 [00:34<14:02,  5.40s/it]
# (train_func pid=487477)
#   5%|▍         | 8/163 [00:39<14:11,  5.49s/it]
# (train_func pid=487477)
#   6%|▌         | 9/163 [00:45<14:16,  5.56s/it]
# (train_func pid=487477)
#   6%|▌         | 10/163 [00:51<14:30,  5.69s/it]
# (train_func pid=487477)
#   7%|▋         | 11/163 [00:57<14:33,  5.75s/it]
# (train_func pid=487477)
#   7%|▋         | 12/163 [01:03<14:28,  5.75s/it]
# (train_func pid=487477)
#   8%|▊         | 13/163 [01:09<14:24,  5.76s/it]
# (train_func pid=487477)
#   9%|▊         | 14/163 [01:14<14:16,  5.75s/it]
# (train_func pid=487477)
#   9%|▉         | 15/163 [01:20<14:08,  5.74s/it]
# (train_func pid=487477)
#  10%|▉         | 16/163 [01:26<14:02,  5.73s/it]
# (train_func pid=487477)
#  10%|█         | 17/163 [01:31<13:57,  5.74s/it]
# (train_func pid=487477)
#  11%|█         | 18/163 [01:37<13:51,  5.73s/it]
# (train_func pid=487477)
#  12%|█▏        | 19/163 [01:43<13:44,  5.72s/it]
# (train_func pid=487477)
#  12%|█▏        | 20/163 [01:49<13:39,  5.73s/it]
# (train_func pid=487477)
#  13%|█▎        | 21/163 [01:54<13:35,  5.75s/it]
# (train_func pid=487477)
#  13%|█▎        | 22/163 [02:00<13:35,  5.79s/it]
# (train_func pid=487477)
#  14%|█▍        | 23/163 [02:06<13:28,  5.77s/it]
# (train_func pid=487477)
#  15%|█▍        | 24/163 [02:12<13:22,  5.78s/it]
# (train_func pid=487477)
#  15%|█▌        | 25/163 [02:18<13:15,  5.77s/it]
# (train_func pid=487477)
#  16%|█▌        | 26/163 [02:23<13:08,  5.76s/it]
# (train_func pid=487477)
#  17%|█▋        | 27/163 [02:29<13:01,  5.75s/it]
# (train_func pid=487477)
#  17%|█▋        | 28/163 [02:35<12:54,  5.74s/it]
# (train_func pid=487477)
#  18%|█▊        | 29/163 [02:40<12:47,  5.73s/it]
# (train_func pid=487477)
#  18%|█▊        | 30/163 [02:46<12:41,  5.73s/it]
# (train_func pid=487477)
#  19%|█▉        | 31/163 [02:52<12:36,  5.73s/it]
# (train_func pid=487477)
#  20%|█▉        | 32/163 [02:58<12:29,  5.73s/it]
# (train_func pid=487477)
#  20%|██        | 33/163 [03:04<12:31,  5.78s/it]
# (train_func pid=487477)
#  21%|██        | 34/163 [03:09<12:23,  5.76s/it]
# (train_func pid=487477)
#  21%|██▏       | 35/163 [03:15<12:19,  5.77s/it]
# (train_func pid=487477)
#  22%|██▏       | 36/163 [03:21<12:18,  5.82s/it]
# (train_func pid=487477)
#  23%|██▎       | 37/163 [03:27<12:08,  5.78s/it]
# (train_func pid=487477)
#  23%|██▎       | 38/163 [03:33<12:07,  5.82s/it]
# (train_func pid=487477)
#  24%|██▍       | 39/163 [03:38<11:58,  5.80s/it]
# (train_func pid=487477)
#  25%|██▍       | 40/163 [03:44<12:02,  5.87s/it]
# (train_func pid=487477)
#  25%|██▌       | 41/163 [03:50<11:52,  5.84s/it]
# (train_func pid=487477)
#  26%|██▌       | 42/163 [03:56<11:47,  5.84s/it]
# (train_func pid=487477)
#  26%|██▋       | 43/163 [04:02<11:37,  5.81s/it]
# (train_func pid=487477)
#  27%|██▋       | 44/163 [04:07<11:29,  5.80s/it]
# (train_func pid=487477)
#  28%|██▊       | 45/163 [04:13<11:20,  5.77s/it]
# (train_func pid=487477)
#  28%|██▊       | 46/163 [04:19<11:12,  5.75s/it]
# (train_func pid=487477)
#  29%|██▉       | 47/163 [04:25<11:06,  5.75s/it]
# (train_func pid=487477)
#  29%|██▉       | 48/163 [04:30<11:02,  5.76s/it]
# (train_func pid=487477)
#  30%|███       | 49/163 [04:36<10:59,  5.78s/it]
# (train_func pid=487477)
#  31%|███       | 50/163 [04:42<10:54,  5.79s/it]
# (train_func pid=487477)
#  31%|███▏      | 51/163 [04:48<10:47,  5.78s/it]
# (train_func pid=487477)
#  32%|███▏      | 52/163 [04:54<10:41,  5.78s/it]
# (train_func pid=487477)
#  33%|███▎      | 53/163 [04:59<10:34,  5.77s/it]
# (train_func pid=487477)
#  33%|███▎      | 54/163 [05:05<10:30,  5.79s/it]
# (train_func pid=487477)
#  34%|███▎      | 55/163 [05:11<10:24,  5.78s/it]
# (train_func pid=487477)
#  34%|███▍      | 56/163 [05:17<10:19,  5.79s/it]
# (train_func pid=487477)
#  35%|███▍      | 57/163 [05:23<10:19,  5.84s/it]
# (train_func pid=487477)
#  36%|███▌      | 58/163 [05:29<10:16,  5.87s/it]
# (train_func pid=487477)
#  36%|███▌      | 59/163 [05:35<10:12,  5.89s/it]
# (train_func pid=487477)
#  37%|███▋      | 60/163 [05:40<10:03,  5.86s/it]
# (train_func pid=487477)
#  37%|███▋      | 61/163 [05:46<09:53,  5.82s/it]
# (train_func pid=487477)
#  38%|███▊      | 62/163 [05:52<09:46,  5.81s/it]
# (train_func pid=487477)
#  39%|███▊      | 63/163 [05:58<09:40,  5.80s/it]
# (train_func pid=487477)
#  39%|███▉      | 64/163 [06:03<09:32,  5.78s/it]
# (train_func pid=487477)
#  40%|███▉      | 65/163 [06:09<09:26,  5.78s/it]
# (train_func pid=487477)
#  40%|████      | 66/163 [06:15<09:21,  5.79s/it]
# (train_func pid=487477)
#  41%|████      | 67/163 [06:21<09:15,  5.78s/it]
# (train_func pid=487477)
#  42%|████▏     | 68/163 [06:27<09:09,  5.78s/it]
# (train_func pid=487477)
#  42%|████▏     | 69/163 [06:32<09:04,  5.80s/it]
# (train_func pid=487477)
#  43%|████▎     | 70/163 [06:38<08:58,  5.79s/it]
# (train_func pid=487477)
#  44%|████▎     | 71/163 [06:44<08:52,  5.79s/it]
# (train_func pid=487477)
#  44%|████▍     | 72/163 [06:50<08:45,  5.78s/it]
# (train_func pid=487477)
#  45%|████▍     | 73/163 [06:55<08:41,  5.79s/it]
# (train_func pid=487477)
#  45%|████▌     | 74/163 [07:01<08:36,  5.80s/it]
# (train_func pid=487477)
#  46%|████▌     | 75/163 [07:07<08:30,  5.80s/it]
# (train_func pid=487477)
#  47%|████▋     | 76/163 [07:13<08:24,  5.80s/it]
# (train_func pid=487477)
#  47%|████▋     | 77/163 [07:19<08:20,  5.81s/it]
# (train_func pid=487477)
#  48%|████▊     | 78/163 [07:25<08:17,  5.85s/it]
# (train_func pid=487477)
#  48%|████▊     | 79/163 [07:31<08:13,  5.87s/it]
# (train_func pid=487477)
#  49%|████▉     | 80/163 [07:36<08:07,  5.87s/it]
# (train_func pid=487477)
#  50%|████▉     | 81/163 [07:42<07:58,  5.84s/it]
# (train_func pid=487477)
#  50%|█████     | 82/163 [07:48<07:51,  5.82s/it]
# (train_func pid=487477)
#  51%|█████     | 83/163 [07:54<07:46,  5.83s/it]
# (train_func pid=487477)
#  52%|█████▏    | 84/163 [08:00<07:41,  5.84s/it]
# (train_func pid=487477)
#  52%|█████▏    | 85/163 [08:06<07:35,  5.84s/it]
# (train_func pid=487477)
#  53%|█████▎    | 86/163 [08:11<07:30,  5.85s/it]
# (train_func pid=487477)
#  53%|█████▎    | 87/163 [08:17<07:25,  5.86s/it]
# (train_func pid=487477)
#  54%|█████▍    | 88/163 [08:23<07:23,  5.92s/it]
# (train_func pid=487477)
#  55%|█████▍    | 89/163 [08:29<07:20,  5.95s/it]
# (train_func pid=487477)
#  55%|█████▌    | 90/163 [08:35<07:12,  5.92s/it]
# (train_func pid=487477)
#  56%|█████▌    | 91/163 [08:41<07:05,  5.91s/it]
# (train_func pid=487477)
#  56%|█████▋    | 92/163 [08:47<06:56,  5.86s/it]
# (train_func pid=487477)
#  57%|█████▋    | 93/163 [08:53<06:47,  5.83s/it]
# (train_func pid=487477)
#  58%|█████▊    | 94/163 [08:58<06:41,  5.81s/it]
# (train_func pid=487477)
#  58%|█████▊    | 95/163 [09:04<06:39,  5.87s/it]
# (train_func pid=487477)
#  59%|█████▉    | 96/163 [09:10<06:33,  5.87s/it]
# (train_func pid=487477)
#  60%|█████▉    | 97/163 [09:16<06:24,  5.83s/it]
# (train_func pid=487477)
#  60%|██████    | 98/163 [09:22<06:17,  5.81s/it]
# (train_func pid=487477)
#  61%|██████    | 99/163 [09:28<06:11,  5.80s/it]
# (train_func pid=487477)
#  61%|██████▏   | 100/163 [09:33<06:03,  5.77s/it]
# (train_func pid=487477)
#  62%|██████▏   | 101/163 [09:39<05:57,  5.77s/it]
# (train_func pid=487477)
#  63%|██████▎   | 102/163 [09:45<05:53,  5.80s/it]
# (train_func pid=487477)
#  63%|██████▎   | 103/163 [09:51<05:47,  5.80s/it]
# (train_func pid=487477)
#  64%|██████▍   | 104/163 [09:56<05:40,  5.78s/it]
# (train_func pid=487477)
#  64%|██████▍   | 105/163 [10:02<05:34,  5.76s/it]
# (train_func pid=487477)
#  65%|██████▌   | 106/163 [10:08<05:28,  5.77s/it]
# (train_func pid=487477)
#  66%|██████▌   | 107/163 [10:14<05:26,  5.82s/it]
# (train_func pid=487477)
#  66%|██████▋   | 108/163 [10:20<05:20,  5.83s/it]
# (train_func pid=487477)
#  67%|██████▋   | 109/163 [10:25<05:12,  5.78s/it]
# (train_func pid=487477)
#  67%|██████▋   | 110/163 [10:31<05:05,  5.77s/it]
# (train_func pid=487477)
#  68%|██████▊   | 111/163 [10:37<04:59,  5.76s/it]
# (train_func pid=487477)
#  69%|██████▊   | 112/163 [10:43<04:53,  5.76s/it]
# (train_func pid=487477)
#  69%|██████▉   | 113/163 [10:48<04:47,  5.75s/it]
# (train_func pid=487477)
#  70%|██████▉   | 114/163 [10:54<04:40,  5.73s/it]
# (train_func pid=487477)
#  71%|███████   | 115/163 [11:00<04:33,  5.70s/it]
# (train_func pid=487477)
#  71%|███████   | 116/163 [11:05<04:27,  5.69s/it]
# (train_func pid=487477)
#  72%|███████▏  | 117/163 [11:11<04:20,  5.67s/it]
# (train_func pid=487477)
#  72%|███████▏  | 118/163 [11:17<04:14,  5.67s/it]
# (train_func pid=487477)
#  73%|███████▎  | 119/163 [11:22<04:09,  5.67s/it]
# (train_func pid=487477)
#  74%|███████▎  | 120/163 [11:28<04:03,  5.67s/it]
# (train_func pid=487477)
#  74%|███████▍  | 121/163 [11:34<04:02,  5.77s/it]
# (train_func pid=487477)
#  75%|███████▍  | 122/163 [11:40<03:55,  5.74s/it]
# (train_func pid=487477)
#  75%|███████▌  | 123/163 [11:45<03:49,  5.73s/it]
# (train_func pid=487477)
#  76%|███████▌  | 124/163 [11:51<03:43,  5.72s/it]
# (train_func pid=487477)
#  77%|███████▋  | 125/163 [11:57<03:38,  5.75s/it]
# (train_func pid=487477)
#  77%|███████▋  | 126/163 [12:03<03:31,  5.73s/it]
# (train_func pid=487477)
#  78%|███████▊  | 127/163 [12:09<03:28,  5.79s/it]
# (train_func pid=487477)
#  79%|███████▊  | 128/163 [12:14<03:22,  5.80s/it]
# (train_func pid=487477)
#  79%|███████▉  | 129/163 [12:20<03:16,  5.78s/it]
# (train_func pid=487477)
#  80%|███████▉  | 130/163 [12:26<03:10,  5.77s/it]
# (train_func pid=487477)
#  80%|████████  | 131/163 [12:31<03:03,  5.73s/it]
# (train_func pid=487477)
#  81%|████████  | 132/163 [12:37<02:58,  5.75s/it]
# (train_func pid=487477)
#  82%|████████▏ | 133/163 [12:43<02:51,  5.73s/it]
# (train_func pid=487477)
#  82%|████████▏ | 134/163 [12:49<02:45,  5.71s/it]
# (train_func pid=487477)
#  83%|████████▎ | 135/163 [12:54<02:40,  5.74s/it]
# (train_func pid=487477)
#  83%|████████▎ | 136/163 [13:00<02:35,  5.74s/it]
# (train_func pid=487477)
#  84%|████████▍ | 137/163 [13:06<02:29,  5.73s/it]
# (train_func pid=487477)
#  85%|████████▍ | 138/163 [13:12<02:23,  5.73s/it]
# (train_func pid=487477)
#  85%|████████▌ | 139/163 [13:17<02:17,  5.72s/it]
# (train_func pid=487477)
#  86%|████████▌ | 140/163 [13:23<02:12,  5.74s/it]
# (train_func pid=487477)
#  87%|████████▋ | 141/163 [13:29<02:06,  5.75s/it]
# (train_func pid=487477)
#  87%|████████▋ | 142/163 [13:35<02:00,  5.74s/it]
# (train_func pid=487477)
#  88%|████████▊ | 143/163 [13:40<01:54,  5.73s/it]
# (train_func pid=487477)
#  88%|████████▊ | 144/163 [13:46<01:49,  5.76s/it]
# (train_func pid=487477)
#  89%|████████▉ | 145/163 [13:52<01:44,  5.80s/it]
# (train_func pid=487477)
#  90%|████████▉ | 146/163 [13:58<01:38,  5.81s/it]
# (train_func pid=487477)
#  90%|█████████ | 147/163 [14:04<01:32,  5.81s/it]
# (train_func pid=487477)
#  91%|█████████ | 148/163 [14:10<01:28,  5.89s/it]
# (train_func pid=487477)
#  91%|█████████▏| 149/163 [14:16<01:23,  5.93s/it]
# (train_func pid=487477)
#  92%|█████████▏| 150/163 [14:22<01:16,  5.92s/it]
# (train_func pid=487477)
#  93%|█████████▎| 151/163 [14:27<01:10,  5.87s/it]
# (train_func pid=487477)
#  93%|█████████▎| 152/163 [14:33<01:04,  5.83s/it]
# (train_func pid=487477)
#  94%|█████████▍| 153/163 [14:39<00:58,  5.82s/it]
# (train_func pid=487477)
#  94%|█████████▍| 154/163 [14:45<00:52,  5.80s/it]
# (train_func pid=487477)
#  95%|█████████▌| 155/163 [14:50<00:46,  5.80s/it]
# (train_func pid=487477)
#  96%|█████████▌| 156/163 [14:56<00:40,  5.79s/it]
# (train_func pid=487477)
#  96%|█████████▋| 157/163 [15:02<00:34,  5.81s/it]
# (train_func pid=487477)
#  97%|█████████▋| 158/163 [15:08<00:29,  5.82s/it]
# (train_func pid=487477)
#  98%|█████████▊| 159/163 [15:14<00:23,  5.83s/it]
# (train_func pid=487477)
#  98%|█████████▊| 160/163 [15:20<00:17,  5.83s/it]
# (train_func pid=487477)
#  99%|█████████▉| 161/163 [15:25<00:11,  5.81s/it]
# (train_func pid=487477)
#  99%|█████████▉| 162/163 [15:31<00:05,  5.81s/it]
# (train_func pid=487477) {'eval_loss': 1.095703363418579, 'eval_runtime': 942.821, 'eval_samples_per_second': 2.765, 'eval_steps_per_second': 0.173, 'epoch': 0.0}
# (train_func pid=487477)
#                                                t]
#  10%|█         | 2/20 [20:59<47:12, 157.36s/it]
# 100%|██████████| 163/163 [15:37<00:00,  5.69s/it]
#
# (train_func pid=487477) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/root/ray_results/train_func_2024-05-29_16-03-19/train_func_f74df_00000_0_lr=0.0001_2024-05-29_16-03-19/checkpoint_000000)
#  15%|█▌        | 3/20 [23:34<2:46:20, 587.09s/it]
# (train_func pid=487477) {'loss': 1.3568, 'grad_norm': 3.956453800201416, 'learning_rate': 0.0001, 'epoch': 0.0}
#  20%|██        | 4/20 [26:07<1:50:48, 415.56s/it]
# (train_func pid=487477)
#   0%|          | 0/163 [00:00<?, ?it/s]
# (train_func pid=487477)
#   1%|          | 2/163 [00:05<07:52,  2.94s/it]
# (train_func pid=487477)
#   2%|▏         | 3/163 [00:11<11:06,  4.17s/it]
# (train_func pid=487477)
#   2%|▏         | 4/163 [00:17<12:39,  4.78s/it]
# (train_func pid=487477)
#   3%|▎         | 5/163 [00:23<13:33,  5.15s/it]
# (train_func pid=487477)
#   4%|▎         | 6/163 [00:29<14:07,  5.40s/it]
# (train_func pid=487477)
#   4%|▍         | 7/163 [00:35<14:24,  5.54s/it]
# (train_func pid=487477)
#   5%|▍         | 8/163 [00:40<14:29,  5.61s/it]
# (train_func pid=487477)
#   6%|▌         | 9/163 [00:46<14:30,  5.65s/it]
# (train_func pid=487477)
#   6%|▌         | 10/163 [00:52<14:28,  5.68s/it]
# (train_func pid=487477)
#   7%|▋         | 11/163 [00:58<14:26,  5.70s/it]
# (train_func pid=487477)
#   7%|▋         | 12/163 [01:03<14:23,  5.72s/it]
# (train_func pid=487477)
#   8%|▊         | 13/163 [01:09<14:21,  5.74s/it]
# (train_func pid=487477)
#   9%|▊         | 14/163 [01:15<14:22,  5.79s/it]
# (train_func pid=487477)
#   9%|▉         | 15/163 [01:21<14:20,  5.82s/it]
# (train_func pid=487477)
#  10%|▉         | 16/163 [01:27<14:13,  5.81s/it]
# (train_func pid=487477)
#  10%|█         | 17/163 [01:33<14:12,  5.84s/it]
# (train_func pid=487477)
#  11%|█         | 18/163 [01:38<14:02,  5.81s/it]
# (train_func pid=487477)
#  12%|█▏        | 19/163 [01:44<13:56,  5.81s/it]
# (train_func pid=487477)
#  12%|█▏        | 20/163 [01:50<13:49,  5.80s/it]
# (train_func pid=487477)
#  13%|█▎        | 21/163 [01:56<13:43,  5.80s/it]
# (train_func pid=487477)
#  13%|█▎        | 22/163 [02:02<13:39,  5.81s/it]
# (train_func pid=487477)
#  14%|█▍        | 23/163 [02:07<13:33,  5.81s/it]
# (train_func pid=487477)
#  15%|█▍        | 24/163 [02:13<13:27,  5.81s/it]
# (train_func pid=487477)
#  15%|█▌        | 25/163 [02:19<13:20,  5.80s/it]
# (train_func pid=487477)
#  16%|█▌        | 26/163 [02:25<13:13,  5.79s/it]
# (train_func pid=487477)
#  17%|█▋        | 27/163 [02:31<13:04,  5.77s/it]
# (train_func pid=487477)
#  17%|█▋        | 28/163 [02:36<12:56,  5.76s/it]
# (train_func pid=487477)
#  18%|█▊        | 29/163 [02:42<12:52,  5.77s/it]
# (train_func pid=487477)
#  18%|█▊        | 30/163 [02:48<12:49,  5.78s/it]
# (train_func pid=487477)
#  19%|█▉        | 31/163 [02:54<12:43,  5.78s/it]
# (train_func pid=487477)
#  20%|█▉        | 32/163 [02:59<12:37,  5.78s/it]
# (train_func pid=487477)
#  20%|██        | 33/163 [03:05<12:35,  5.81s/it]
# (train_func pid=487477)
#  21%|██        | 34/163 [03:11<12:26,  5.79s/it]
# (train_func pid=487477)
#  21%|██▏       | 35/163 [03:17<12:37,  5.92s/it]
# (train_func pid=487477)
#  22%|██▏       | 36/163 [03:23<12:36,  5.95s/it]
# (train_func pid=487477)
#  23%|██▎       | 37/163 [03:29<12:29,  5.95s/it]
# (train_func pid=487477)
#  23%|██▎       | 38/163 [03:35<12:17,  5.90s/it]
# (train_func pid=487477)
#  24%|██▍       | 39/163 [03:41<12:06,  5.86s/it]
# (train_func pid=487477)
#  25%|██▍       | 40/163 [03:47<12:06,  5.91s/it]
# (train_func pid=487477)
#  25%|██▌       | 41/163 [03:53<12:02,  5.93s/it]
# (train_func pid=487477)
#  26%|██▌       | 42/163 [03:59<11:54,  5.90s/it]
# (train_func pid=487477)
#  26%|██▋       | 43/163 [04:05<11:52,  5.94s/it]
# (train_func pid=487477)
#  27%|██▋       | 44/163 [04:11<11:50,  5.97s/it]
# (train_func pid=487477)
#  28%|██▊       | 45/163 [04:17<11:41,  5.95s/it]
# (train_func pid=487477)
#  28%|██▊       | 46/163 [04:22<11:34,  5.93s/it]
# (train_func pid=487477)
#  29%|██▉       | 47/163 [04:28<11:21,  5.88s/it]
# (train_func pid=487477)
#  29%|██▉       | 48/163 [04:34<11:19,  5.91s/it]
# (train_func pid=487477)
#  30%|███       | 49/163 [04:40<11:09,  5.87s/it]
# (train_func pid=487477)
#  31%|███       | 50/163 [04:46<11:01,  5.85s/it]
# (train_func pid=487477)
#  31%|███▏      | 51/163 [04:52<10:52,  5.83s/it]
# (train_func pid=487477)
#  32%|███▏      | 52/163 [04:57<10:45,  5.82s/it]
# (train_func pid=487477)
#  33%|███▎      | 53/163 [05:03<10:39,  5.81s/it]
# (train_func pid=487477)
#  33%|███▎      | 54/163 [05:09<10:34,  5.83s/it]
# (train_func pid=487477)
#  34%|███▎      | 55/163 [05:15<10:29,  5.83s/it]
# (train_func pid=487477)
#  34%|███▍      | 56/163 [05:21<10:26,  5.86s/it]
# (train_func pid=487477)
#  35%|███▍      | 57/163 [05:27<10:17,  5.82s/it]
# (train_func pid=487477)
#  36%|███▌      | 58/163 [05:32<10:10,  5.81s/it]
# (train_func pid=487477)
#  36%|███▌      | 59/163 [05:38<10:03,  5.80s/it]
# (train_func pid=487477)
#  37%|███▋      | 60/163 [05:44<09:58,  5.81s/it]
# (train_func pid=487477)
#  37%|███▋      | 61/163 [05:50<09:50,  5.79s/it]
# (train_func pid=487477)
#  38%|███▊      | 62/163 [05:55<09:45,  5.80s/it]
# (train_func pid=487477)
#  39%|███▊      | 63/163 [06:01<09:39,  5.80s/it]
# (train_func pid=487477)
#  39%|███▉      | 64/163 [06:07<09:32,  5.79s/it]
# (train_func pid=487477)
#  40%|███▉      | 65/163 [06:13<09:27,  5.79s/it]
# (train_func pid=487477)
#  40%|████      | 66/163 [06:19<09:19,  5.77s/it]
# (train_func pid=487477)
#  41%|████      | 67/163 [06:24<09:12,  5.76s/it]
# (train_func pid=487477)
#  42%|████▏     | 68/163 [06:30<09:07,  5.76s/it]
# (train_func pid=487477)
#  42%|████▏     | 69/163 [06:36<09:08,  5.84s/it]
# (train_func pid=487477)
#  43%|████▎     | 70/163 [06:42<09:02,  5.83s/it]
# (train_func pid=487477)
#  44%|████▎     | 71/163 [06:48<08:55,  5.82s/it]
# (train_func pid=487477)
#  44%|████▍     | 72/163 [06:54<08:52,  5.85s/it]
# (train_func pid=487477)
#  45%|████▍     | 73/163 [07:00<08:51,  5.91s/it]
# (train_func pid=487477)
#  45%|████▌     | 74/163 [07:06<08:45,  5.90s/it]
# (train_func pid=487477)
#  46%|████▌     | 75/163 [07:11<08:36,  5.87s/it]
# (train_func pid=487477)
#  47%|████▋     | 76/163 [07:17<08:31,  5.88s/it]
# (train_func pid=487477)
#  47%|████▋     | 77/163 [07:23<08:26,  5.88s/it]
# (train_func pid=487477)
#  48%|████▊     | 78/163 [07:29<08:18,  5.86s/it]
# (train_func pid=487477)
#  48%|████▊     | 79/163 [07:35<08:11,  5.85s/it]
# (train_func pid=487477)
#  49%|████▉     | 80/163 [07:41<08:04,  5.83s/it]
# (train_func pid=487477)
#  50%|████▉     | 81/163 [07:46<07:58,  5.83s/it]
# (train_func pid=487477)
#  50%|█████     | 82/163 [07:52<07:50,  5.81s/it]
# (train_func pid=487477)
#  51%|█████     | 83/163 [07:58<07:55,  5.95s/it]
# (train_func pid=487477)
#  52%|█████▏    | 84/163 [08:05<08:14,  6.26s/it]
# (train_func pid=487477)
#  52%|█████▏    | 85/163 [08:12<08:21,  6.42s/it]
# (train_func pid=487477)
#  53%|█████▎    | 86/163 [08:19<08:19,  6.49s/it]
# (train_func pid=487477)
#  53%|█████▎    | 87/163 [08:26<08:18,  6.56s/it]
# (train_func pid=487477)
#  54%|█████▍    | 88/163 [08:31<07:56,  6.35s/it]
# (train_func pid=487477)
#  55%|█████▍    | 89/163 [08:37<07:35,  6.15s/it]
# (train_func pid=487477)
#  55%|█████▌    | 90/163 [08:43<07:29,  6.15s/it]
# (train_func pid=487477)
#  56%|█████▌    | 91/163 [08:50<07:37,  6.36s/it]
# (train_func pid=487477)
#  56%|█████▋    | 92/163 [08:56<07:30,  6.35s/it]
# (train_func pid=487477)
#  57%|█████▋    | 93/163 [09:02<07:13,  6.20s/it]
# (train_func pid=487477)
#  58%|█████▊    | 94/163 [09:08<07:00,  6.09s/it]
# (train_func pid=487477)
#  58%|█████▊    | 95/163 [09:14<06:51,  6.05s/it]
# (train_func pid=487477)
#  59%|█████▉    | 96/163 [09:20<06:51,  6.14s/it]
# (train_func pid=487477)
#  60%|█████▉    | 97/163 [09:27<07:00,  6.37s/it]
# (train_func pid=487477)
#  60%|██████    | 98/163 [09:33<06:50,  6.31s/it]
# (train_func pid=487477)
#  61%|██████    | 99/163 [09:39<06:35,  6.18s/it]
# (train_func pid=487477)
#  61%|██████▏   | 100/163 [09:45<06:26,  6.13s/it]
# (train_func pid=487477)
#  62%|██████▏   | 101/163 [09:51<06:15,  6.06s/it]
# (train_func pid=487477)
#  63%|██████▎   | 102/163 [09:57<06:06,  6.00s/it]
# (train_func pid=487477)
#  63%|██████▎   | 103/163 [10:03<05:56,  5.93s/it]
# (train_func pid=487477)
#  64%|██████▍   | 104/163 [10:09<05:47,  5.88s/it]
# (train_func pid=487477)
#  64%|██████▍   | 105/163 [10:15<05:40,  5.88s/it]
# (train_func pid=487477)
#  65%|██████▌   | 106/163 [10:20<05:35,  5.89s/it]
# (train_func pid=487477)
#  66%|██████▌   | 107/163 [10:26<05:27,  5.85s/it]
# (train_func pid=487477)
#  66%|██████▋   | 108/163 [10:32<05:20,  5.84s/it]
# (train_func pid=487477)
#  67%|██████▋   | 109/163 [10:38<05:13,  5.80s/it]
# (train_func pid=487477)
#  67%|██████▋   | 110/163 [10:43<05:06,  5.78s/it]
# (train_func pid=487477)
#  68%|██████▊   | 111/163 [10:49<05:00,  5.78s/it]
# (train_func pid=487477)
#  69%|██████▊   | 112/163 [10:55<04:53,  5.75s/it]
# (train_func pid=487477)
#  69%|██████▉   | 113/163 [11:01<04:47,  5.76s/it]
# (train_func pid=487477)
#  70%|██████▉   | 114/163 [11:07<04:45,  5.82s/it]
# (train_func pid=487477)
#  71%|███████   | 115/163 [11:12<04:37,  5.79s/it]
# (train_func pid=487477)
#  71%|███████   | 116/163 [11:18<04:31,  5.79s/it]
# (train_func pid=487477)
#  72%|███████▏  | 117/163 [11:24<04:27,  5.81s/it]
# (train_func pid=487477)
#  72%|███████▏  | 118/163 [11:30<04:20,  5.78s/it]
# (train_func pid=487477)
#  73%|███████▎  | 119/163 [11:35<04:13,  5.75s/it]
# (train_func pid=487477)
#  74%|███████▎  | 120/163 [11:41<04:09,  5.80s/it]
# (train_func pid=487477)
#  74%|███████▍  | 121/163 [11:47<04:05,  5.84s/it]
# (train_func pid=487477)
#  75%|███████▍  | 122/163 [11:53<03:59,  5.84s/it]
# (train_func pid=487477)
#  75%|███████▌  | 123/163 [11:59<03:54,  5.86s/it]
# (train_func pid=487477)
#  76%|███████▌  | 124/163 [12:05<03:47,  5.84s/it]
# (train_func pid=487477)
#  77%|███████▋  | 125/163 [12:11<03:40,  5.81s/it]
# (train_func pid=487477)
#  77%|███████▋  | 126/163 [12:16<03:33,  5.78s/it]
# (train_func pid=487477)
#  78%|███████▊  | 127/163 [12:22<03:27,  5.76s/it]
# (train_func pid=487477)
#  79%|███████▊  | 128/163 [12:28<03:21,  5.77s/it]
# (train_func pid=487477)
#  79%|███████▉  | 129/163 [12:34<03:16,  5.77s/it]
# (train_func pid=487477)
#  80%|███████▉  | 130/163 [12:39<03:10,  5.76s/it]
# (train_func pid=487477)
#  80%|████████  | 131/163 [12:45<03:06,  5.82s/it]
# (train_func pid=487477)
#  81%|████████  | 132/163 [12:51<03:03,  5.90s/it]
# (train_func pid=487477)
#  82%|████████▏ | 133/163 [12:57<02:55,  5.85s/it]
# (train_func pid=487477)
#  82%|████████▏ | 134/163 [13:03<02:48,  5.82s/it]
# (train_func pid=487477)
#  83%|████████▎ | 135/163 [13:08<02:42,  5.79s/it]
# (train_func pid=487477)
#  83%|████████▎ | 136/163 [13:14<02:35,  5.77s/it]
# (train_func pid=487477)
#  84%|████████▍ | 137/163 [13:20<02:31,  5.82s/it]
# (train_func pid=487477)
#  85%|████████▍ | 138/163 [13:26<02:25,  5.81s/it]
# (train_func pid=487477)
#  85%|████████▌ | 139/163 [13:32<02:18,  5.79s/it]
# (train_func pid=487477)
#  86%|████████▌ | 140/163 [13:37<02:13,  5.80s/it]
# (train_func pid=487477)
#  87%|████████▋ | 141/163 [13:43<02:08,  5.82s/it]
# (train_func pid=487477)
#  87%|████████▋ | 142/163 [13:49<02:02,  5.82s/it]
# (train_func pid=487477)
#  88%|████████▊ | 143/163 [13:55<01:56,  5.82s/it]
# (train_func pid=487477)
#  88%|████████▊ | 144/163 [14:01<01:50,  5.80s/it]
# (train_func pid=487477)
#  89%|████████▉ | 145/163 [14:07<01:44,  5.80s/it]
# (train_func pid=487477)
#  90%|████████▉ | 146/163 [14:12<01:38,  5.82s/it]
# (train_func pid=487477)
#  90%|█████████ | 147/163 [14:18<01:33,  5.82s/it]
# (train_func pid=487477)
#  91%|█████████ | 148/163 [14:24<01:27,  5.81s/it]
# (train_func pid=487477)
#  91%|█████████▏| 149/163 [14:30<01:21,  5.80s/it]
# (train_func pid=487477)
#  92%|█████████▏| 150/163 [14:36<01:16,  5.86s/it]
# (train_func pid=487477)
#  93%|█████████▎| 151/163 [14:42<01:10,  5.84s/it]
# (train_func pid=487477)
#  93%|█████████▎| 152/163 [14:47<01:04,  5.83s/it]
# (train_func pid=487477)
#  94%|█████████▍| 153/163 [14:53<00:58,  5.82s/it]
# (train_func pid=487477)
#  94%|█████████▍| 154/163 [14:59<00:52,  5.84s/it]
# (train_func pid=487477)
#  95%|█████████▌| 155/163 [15:05<00:47,  5.90s/it]
# (train_func pid=487477)
#  96%|█████████▌| 156/163 [15:11<00:41,  5.87s/it]
# (train_func pid=487477)
#  96%|█████████▋| 157/163 [15:17<00:35,  5.89s/it]
# (train_func pid=487477)
#  97%|█████████▋| 158/163 [15:23<00:29,  5.90s/it]
# (train_func pid=487477)
#  98%|█████████▊| 159/163 [15:29<00:23,  5.88s/it]
# (train_func pid=487477)
#  98%|█████████▊| 160/163 [15:34<00:17,  5.88s/it]
# (train_func pid=487477)
#  99%|█████████▉| 161/163 [15:40<00:11,  5.88s/it]
# (train_func pid=487477)
#  99%|█████████▉| 162/163 [15:46<00:05,  5.88s/it]
# (train_func pid=487477) {'eval_loss': 0.9346609115600586, 'eval_runtime': 958.082, 'eval_samples_per_second': 2.721, 'eval_steps_per_second': 0.17, 'epoch': 0.0}
# (train_func pid=487477)
#
#  20%|██        | 4/20 [42:05<1:50:48, 415.56s/it]
# 100%|██████████| 163/163 [15:52<00:00,  5.77s/it]
#
# (train_func pid=487477) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/root/ray_results/train_func_2024-05-29_16-03-19/train_func_f74df_00000_0_lr=0.0001_2024-05-29_16-03-19/checkpoint_000001)
#  25%|██▌       | 5/20 [44:41<2:46:52, 667.47s/it]
# (train_func pid=487477) {'loss': 1.0755, 'grad_norm': 2.4827215671539307, 'learning_rate': 8.75e-05, 'epoch': 0.01}
#  30%|███       | 6/20 [47:14<1:54:54, 492.45s/it]
# (train_func pid=487477)
#   0%|          | 0/163 [00:00<?, ?it/s]
# (train_func pid=487477)
#   1%|          | 2/163 [00:05<08:00,  2.99s/it]
# (train_func pid=487477)
#   2%|▏         | 3/163 [00:11<11:04,  4.16s/it]
# (train_func pid=487477)
#   2%|▏         | 4/163 [00:17<12:42,  4.80s/it]
# (train_func pid=487477)
#   3%|▎         | 5/163 [00:23<13:34,  5.15s/it]
# (train_func pid=487477)
#   4%|▎         | 6/163 [00:29<14:02,  5.37s/it]
# (train_func pid=487477)
#   4%|▍         | 7/163 [00:35<14:21,  5.52s/it]
# (train_func pid=487477)
#   5%|▍         | 8/163 [00:40<14:29,  5.61s/it]
# (train_func pid=487477)
#   6%|▌         | 9/163 [00:46<14:31,  5.66s/it]
# (train_func pid=487477)
#   6%|▌         | 10/163 [00:52<14:30,  5.69s/it]
# (train_func pid=487477)
#   7%|▋         | 11/163 [00:58<14:27,  5.71s/it]
# (train_func pid=487477)
#   7%|▋         | 12/163 [01:03<14:25,  5.73s/it]
# (train_func pid=487477)
#   8%|▊         | 13/163 [01:09<14:26,  5.78s/it]
# (train_func pid=487477)
#   9%|▊         | 14/163 [01:15<14:27,  5.82s/it]
# (train_func pid=487477)
#   9%|▉         | 15/163 [01:21<14:20,  5.81s/it]
# (train_func pid=487477)
#  10%|▉         | 16/163 [01:27<14:15,  5.82s/it]
# (train_func pid=487477)
#  10%|█         | 17/163 [01:33<14:07,  5.81s/it]
# (train_func pid=487477)
#  11%|█         | 18/163 [01:38<14:00,  5.79s/it]
# (train_func pid=487477)
#  12%|█▏        | 19/163 [01:44<13:53,  5.79s/it]
# (train_func pid=487477)
#  12%|█▏        | 20/163 [01:50<13:46,  5.78s/it]
# (train_func pid=487477)
#  13%|█▎        | 21/163 [01:56<13:40,  5.78s/it]
# (train_func pid=487477)
#  13%|█▎        | 22/163 [02:02<13:36,  5.79s/it]
# (train_func pid=487477)
#  14%|█▍        | 23/163 [02:07<13:32,  5.80s/it]
# (train_func pid=487477)
#  15%|█▍        | 24/163 [02:13<13:26,  5.80s/it]
# (train_func pid=487477)
#  15%|█▌        | 25/163 [02:19<13:18,  5.79s/it]
# (train_func pid=487477)
#  16%|█▌        | 26/163 [02:25<13:19,  5.83s/it]
# (train_func pid=487477)
#  17%|█▋        | 27/163 [02:31<13:11,  5.82s/it]
# (train_func pid=487477)
#  17%|█▋        | 28/163 [02:36<13:03,  5.80s/it]
# (train_func pid=487477)
#  18%|█▊        | 29/163 [02:42<12:56,  5.79s/it]
# (train_func pid=487477)
#  18%|█▊        | 30/163 [02:48<12:50,  5.79s/it]
# (train_func pid=487477)
#  19%|█▉        | 31/163 [02:54<12:43,  5.78s/it]
# (train_func pid=487477)
#  20%|█▉        | 32/163 [03:00<12:38,  5.79s/it]
# (train_func pid=487477)
#  20%|██        | 33/163 [03:05<12:32,  5.79s/it]
# (train_func pid=487477)
#  21%|██        | 34/163 [03:11<12:26,  5.79s/it]
# (train_func pid=487477)
#  21%|██▏       | 35/163 [03:17<12:26,  5.83s/it]
# (train_func pid=487477)
#  22%|██▏       | 36/163 [03:23<12:19,  5.82s/it]
# (train_func pid=487477)
#  23%|██▎       | 37/163 [03:29<12:10,  5.80s/it]
# (train_func pid=487477)
#  23%|██▎       | 38/163 [03:34<12:04,  5.79s/it]
# (train_func pid=487477)
#  24%|██▍       | 39/163 [03:40<11:58,  5.79s/it]
# (train_func pid=487477)
#  25%|██▍       | 40/163 [03:46<11:50,  5.78s/it]
# (train_func pid=487477)
#  25%|██▌       | 41/163 [03:52<11:44,  5.77s/it]
# (train_func pid=487477)
#  26%|██▌       | 42/163 [03:57<11:38,  5.77s/it]
# (train_func pid=487477)
#  26%|██▋       | 43/163 [04:03<11:34,  5.78s/it]
# (train_func pid=487477)
#  27%|██▋       | 44/163 [04:09<11:30,  5.80s/it]
# (train_func pid=487477)
#  28%|██▊       | 45/163 [04:15<11:26,  5.82s/it]
# (train_func pid=487477)
#  28%|██▊       | 46/163 [04:21<11:28,  5.89s/it]
# (train_func pid=487477)
#  29%|██▉       | 47/163 [04:27<11:28,  5.93s/it]
# (train_func pid=487477)
#  29%|██▉       | 48/163 [04:33<11:16,  5.88s/it]
# (train_func pid=487477)
#  30%|███       | 49/163 [04:39<11:07,  5.85s/it]
# (train_func pid=487477)
#  31%|███       | 50/163 [04:44<11:01,  5.85s/it]
# (train_func pid=487477)
#  31%|███▏      | 51/163 [04:50<10:56,  5.87s/it]
# (train_func pid=487477)
#  32%|███▏      | 52/163 [04:56<10:47,  5.84s/it]
# (train_func pid=487477)
#  33%|███▎      | 53/163 [05:02<10:45,  5.87s/it]
# (train_func pid=487477)
#  33%|███▎      | 54/163 [05:08<10:44,  5.91s/it]
# (train_func pid=487477)
#  34%|███▎      | 55/163 [05:14<10:42,  5.95s/it]
# (train_func pid=487477)
#  34%|███▍      | 56/163 [05:20<10:32,  5.91s/it]
# (train_func pid=487477)
#  35%|███▍      | 57/163 [05:26<10:22,  5.88s/it]
# (train_func pid=487477)
#  36%|███▌      | 58/163 [05:32<10:13,  5.84s/it]
# (train_func pid=487477)
#  36%|███▌      | 59/163 [05:37<10:04,  5.81s/it]
# (train_func pid=487477)
#  37%|███▋      | 60/163 [05:43<09:56,  5.79s/it]
# (train_func pid=487477)
#  37%|███▋      | 61/163 [05:49<09:50,  5.79s/it]
# (train_func pid=487477)
#  38%|███▊      | 62/163 [05:55<09:45,  5.79s/it]
# (train_func pid=487477)
#  39%|███▊      | 63/163 [06:00<09:41,  5.81s/it]
# (train_func pid=487477)
#  39%|███▉      | 64/163 [06:06<09:36,  5.82s/it]
# (train_func pid=487477)
#  40%|███▉      | 65/163 [06:12<09:32,  5.84s/it]
# (train_func pid=487477)
#  40%|████      | 66/163 [06:18<09:28,  5.86s/it]
# (train_func pid=487477)
#  41%|████      | 67/163 [06:24<09:21,  5.85s/it]
# (train_func pid=487477)
#  42%|████▏     | 68/163 [06:30<09:12,  5.82s/it]
# (train_func pid=487477)
#  42%|████▏     | 69/163 [06:35<09:05,  5.80s/it]
# (train_func pid=487477)
#  43%|████▎     | 70/163 [06:41<09:05,  5.87s/it]
# (train_func pid=487477)
#  44%|████▎     | 71/163 [06:47<09:03,  5.91s/it]
# (train_func pid=487477)
#  44%|████▍     | 72/163 [06:53<09:01,  5.95s/it]
# (train_func pid=487477)
#  45%|████▍     | 73/163 [06:59<08:51,  5.90s/it]
# (train_func pid=487477)
#  45%|████▌     | 74/163 [07:05<08:42,  5.87s/it]
# (train_func pid=487477)
#  46%|████▌     | 75/163 [07:11<08:49,  6.02s/it]
# (train_func pid=487477)
#  47%|████▋     | 76/163 [07:17<08:36,  5.94s/it]
# (train_func pid=487477)
#  47%|████▋     | 77/163 [07:23<08:26,  5.89s/it]
# (train_func pid=487477)
#  48%|████▊     | 78/163 [07:29<08:18,  5.87s/it]
# (train_func pid=487477)
#  48%|████▊     | 79/163 [07:35<08:10,  5.83s/it]
# (train_func pid=487477)
#  49%|████▉     | 80/163 [07:40<08:03,  5.82s/it]
# (train_func pid=487477)
#  50%|████▉     | 81/163 [07:46<07:57,  5.82s/it]
# (train_func pid=487477)
#  50%|█████     | 82/163 [07:52<07:51,  5.82s/it]
# (train_func pid=487477)
#  51%|█████     | 83/163 [07:58<07:45,  5.82s/it]
# (train_func pid=487477)
#  52%|█████▏    | 84/163 [08:04<07:39,  5.82s/it]
# (train_func pid=487477)
#  52%|█████▏    | 85/163 [08:09<07:33,  5.82s/it]
# (train_func pid=487477)
#  53%|█████▎    | 86/163 [08:15<07:28,  5.83s/it]
# (train_func pid=487477)
#  53%|█████▎    | 87/163 [08:21<07:22,  5.82s/it]
# (train_func pid=487477)
#  54%|█████▍    | 88/163 [08:27<07:15,  5.81s/it]
# (train_func pid=487477)
#  55%|█████▍    | 89/163 [08:33<07:09,  5.80s/it]
# (train_func pid=487477)
#  55%|█████▌    | 90/163 [08:38<07:02,  5.79s/it]
# (train_func pid=487477)
#  56%|█████▌    | 91/163 [08:44<06:57,  5.80s/it]
# (train_func pid=487477)
#  56%|█████▋    | 92/163 [08:50<06:51,  5.80s/it]
# (train_func pid=487477)
#  57%|█████▋    | 93/163 [08:56<06:47,  5.81s/it]
# (train_func pid=487477)
#  58%|█████▊    | 94/163 [09:02<06:40,  5.81s/it]
# (train_func pid=487477)
#  58%|█████▊    | 95/163 [09:07<06:34,  5.81s/it]
# (train_func pid=487477)
#  59%|█████▉    | 96/163 [09:13<06:32,  5.86s/it]
# (train_func pid=487477)
#  60%|█████▉    | 97/163 [09:19<06:25,  5.84s/it]
# (train_func pid=487477)
#  60%|██████    | 98/163 [09:25<06:19,  5.83s/it]
# (train_func pid=487477)
#  61%|██████    | 99/163 [09:31<06:12,  5.82s/it]
# (train_func pid=487477)
#  61%|██████▏   | 100/163 [09:37<06:06,  5.82s/it]
# (train_func pid=487477)
#  62%|██████▏   | 101/163 [09:43<06:01,  5.83s/it]
# (train_func pid=487477)
#  63%|██████▎   | 102/163 [09:48<05:55,  5.83s/it]
# (train_func pid=487477)
#  63%|██████▎   | 103/163 [09:54<05:50,  5.85s/it]
# (train_func pid=487477)
#  64%|██████▍   | 104/163 [10:00<05:44,  5.84s/it]
# (train_func pid=487477)
#  64%|██████▍   | 105/163 [10:06<05:38,  5.83s/it]
# (train_func pid=487477)
#  65%|██████▌   | 106/163 [10:12<05:33,  5.84s/it]
# (train_func pid=487477)
#  66%|██████▌   | 107/163 [10:18<05:26,  5.83s/it]
# (train_func pid=487477)
#  66%|██████▋   | 108/163 [10:23<05:21,  5.84s/it]
# (train_func pid=487477)
#  67%|██████▋   | 109/163 [10:29<05:17,  5.87s/it]
# (train_func pid=487477)
#  67%|██████▋   | 110/163 [10:35<05:14,  5.93s/it]
# (train_func pid=487477)
#  68%|██████▊   | 111/163 [10:41<05:08,  5.92s/it]
# (train_func pid=487477)
#  69%|██████▊   | 112/163 [10:47<05:00,  5.90s/it]
# (train_func pid=487477)
#  69%|██████▉   | 113/163 [10:53<04:54,  5.88s/it]
# (train_func pid=487477)
#  70%|██████▉   | 114/163 [10:59<04:47,  5.86s/it]
# (train_func pid=487477)
#  71%|███████   | 115/163 [11:05<04:43,  5.91s/it]
# (train_func pid=487477)
#  71%|███████   | 116/163 [11:11<04:36,  5.89s/it]
# (train_func pid=487477)
#  72%|███████▏  | 117/163 [11:17<04:29,  5.86s/it]
# (train_func pid=487477)
#  72%|███████▏  | 118/163 [11:22<04:24,  5.89s/it]
# (train_func pid=487477)
#  73%|███████▎  | 119/163 [11:29<04:21,  5.93s/it]
# (train_func pid=487477)
#  74%|███████▎  | 120/163 [11:35<04:16,  5.96s/it]
# (train_func pid=487477)
#  74%|███████▍  | 121/163 [11:40<04:10,  5.95s/it]
# (train_func pid=487477)
#  75%|███████▍  | 122/163 [11:46<04:02,  5.92s/it]
# (train_func pid=487477)
#  75%|███████▌  | 123/163 [11:52<03:55,  5.90s/it]
# (train_func pid=487477)
#  76%|███████▌  | 124/163 [11:58<03:49,  5.88s/it]
# (train_func pid=487477)
#  77%|███████▋  | 125/163 [12:04<03:42,  5.86s/it]
# (train_func pid=487477)
#  77%|███████▋  | 126/163 [12:10<03:36,  5.86s/it]
# (train_func pid=487477)
#  78%|███████▊  | 127/163 [12:16<03:33,  5.93s/it]
# (train_func pid=487477)
#  79%|███████▊  | 128/163 [12:22<03:28,  5.96s/it]
# (train_func pid=487477)
#  79%|███████▉  | 129/163 [12:28<03:21,  5.92s/it]
# (train_func pid=487477)
#  80%|███████▉  | 130/163 [12:33<03:14,  5.89s/it]
# (train_func pid=487477)
#  80%|████████  | 131/163 [12:39<03:08,  5.88s/it]
# (train_func pid=487477)
#  81%|████████  | 132/163 [12:45<03:01,  5.86s/it]
# (train_func pid=487477)
#  82%|████████▏ | 133/163 [12:51<02:57,  5.91s/it]
# (train_func pid=487477)
#  82%|████████▏ | 134/163 [12:57<02:50,  5.89s/it]
# (train_func pid=487477)
#  83%|████████▎ | 135/163 [13:03<02:44,  5.88s/it]
# (train_func pid=487477)
#  83%|████████▎ | 136/163 [13:09<02:38,  5.88s/it]
# (train_func pid=487477)
#  84%|████████▍ | 137/163 [13:15<02:32,  5.86s/it]
# (train_func pid=487477)
#  85%|████████▍ | 138/163 [13:20<02:26,  5.86s/it]
# (train_func pid=487477)
#  85%|████████▌ | 139/163 [13:26<02:20,  5.86s/it]
# (train_func pid=487477)
#  86%|████████▌ | 140/163 [13:32<02:14,  5.84s/it]
# (train_func pid=487477)
#  87%|████████▋ | 141/163 [13:38<02:08,  5.84s/it]
# (train_func pid=487477)
#  87%|████████▋ | 142/163 [13:44<02:02,  5.84s/it]
# (train_func pid=487477)
#  88%|████████▊ | 143/163 [13:50<01:57,  5.85s/it]
# (train_func pid=487477)
#  88%|████████▊ | 144/163 [13:55<01:51,  5.85s/it]
# (train_func pid=487477)
#  89%|████████▉ | 145/163 [14:01<01:45,  5.88s/it]
# (train_func pid=487477)
#  90%|████████▉ | 146/163 [14:07<01:39,  5.86s/it]
# (train_func pid=487477)
#  90%|█████████ | 147/163 [14:13<01:33,  5.83s/it]
# (train_func pid=487477)
#  91%|█████████ | 148/163 [14:19<01:27,  5.81s/it]
# (train_func pid=487477)
#  91%|█████████▏| 149/163 [14:25<01:21,  5.81s/it]
# (train_func pid=487477)
#  92%|█████████▏| 150/163 [14:30<01:15,  5.83s/it]
# (train_func pid=487477)
#  93%|█████████▎| 151/163 [14:36<01:10,  5.90s/it]
# (train_func pid=487477)
#  93%|█████████▎| 152/163 [14:43<01:05,  5.95s/it]
# (train_func pid=487477)
#  94%|█████████▍| 153/163 [14:48<00:59,  5.92s/it]
# (train_func pid=487477)
#  94%|█████████▍| 154/163 [14:54<00:52,  5.89s/it]
# (train_func pid=487477)
#  95%|█████████▌| 155/163 [15:00<00:46,  5.87s/it]
# (train_func pid=487477)
#  96%|█████████▌| 156/163 [15:06<00:40,  5.85s/it]
# (train_func pid=487477)
#  96%|█████████▋| 157/163 [15:12<00:35,  5.84s/it]
# (train_func pid=487477)
#  97%|█████████▋| 158/163 [15:17<00:29,  5.83s/it]
# (train_func pid=487477)
#  98%|█████████▊| 159/163 [15:23<00:23,  5.82s/it]
# (train_func pid=487477)
#  98%|█████████▊| 160/163 [15:29<00:17,  5.81s/it]
# (train_func pid=487477)
#  99%|█████████▉| 161/163 [15:35<00:11,  5.84s/it]
# (train_func pid=487477)
#  99%|█████████▉| 162/163 [15:41<00:05,  5.89s/it]
# (train_func pid=487477) {'eval_loss': 0.810267448425293, 'eval_runtime': 953.0705, 'eval_samples_per_second': 2.735, 'eval_steps_per_second': 0.171, 'epoch': 0.01}
# (train_func pid=487477)
#
#  30%|███       | 6/20 [1:03:07<1:54:54, 492.45s/it]
# 100%|██████████| 163/163 [15:47<00:00,  5.82s/it]
#
# (train_func pid=487477) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/root/ray_results/train_func_2024-05-29_16-03-19/train_func_f74df_00000_0_lr=0.0001_2024-05-29_16-03-19/checkpoint_000002)
#  35%|███▌      | 7/20 [1:05:43<2:30:21, 693.94s/it]
# (train_func pid=487477) {'loss': 0.8239, 'grad_norm': 2.009735345840454, 'learning_rate': 7.500000000000001e-05, 'epoch': 0.01}
#  40%|████      | 8/20 [1:08:16<1:44:21, 521.80s/it]
# (train_func pid=487477)
#   0%|          | 0/163 [00:00<?, ?it/s]
# (train_func pid=487477)
#   1%|          | 2/163 [00:05<07:49,  2.91s/it]
# (train_func pid=487477)
#   2%|▏         | 3/163 [00:11<11:03,  4.14s/it]
# (train_func pid=487477)
#   2%|▏         | 4/163 [00:17<12:35,  4.75s/it]
# (train_func pid=487477)
#   3%|▎         | 5/163 [00:23<13:36,  5.17s/it]
# (train_func pid=487477)
#   4%|▎         | 6/163 [00:29<14:06,  5.39s/it]
# (train_func pid=487477)
#   4%|▍         | 7/163 [00:35<14:20,  5.52s/it]
# (train_func pid=487477)
#   5%|▍         | 8/163 [00:40<14:30,  5.62s/it]
# (train_func pid=487477)
#   6%|▌         | 9/163 [00:46<14:35,  5.68s/it]
# (train_func pid=487477)
#   6%|▌         | 10/163 [00:52<14:41,  5.76s/it]
# (train_func pid=487477)
#   7%|▋         | 11/163 [00:58<14:50,  5.86s/it]
# (train_func pid=487477)
#   7%|▋         | 12/163 [01:04<14:49,  5.89s/it]
# (train_func pid=487477)
#   8%|▊         | 13/163 [01:10<14:45,  5.90s/it]
# (train_func pid=487477)
#   9%|▊         | 14/163 [01:16<14:34,  5.87s/it]
# (train_func pid=487477)
#   9%|▉         | 15/163 [01:22<14:24,  5.84s/it]
# (train_func pid=487477)
#  10%|▉         | 16/163 [01:28<14:20,  5.86s/it]
# (train_func pid=487477)
#  10%|█         | 17/163 [01:34<14:23,  5.91s/it]
# (train_func pid=487477)
#  11%|█         | 18/163 [01:40<14:24,  5.96s/it]
# (train_func pid=487477)
#  12%|█▏        | 19/163 [01:46<14:22,  5.99s/it]
# (train_func pid=487477)
#  12%|█▏        | 20/163 [01:52<14:11,  5.96s/it]
# (train_func pid=487477)
#  13%|█▎        | 21/163 [01:58<14:02,  5.93s/it]
# (train_func pid=487477)
#  13%|█▎        | 22/163 [02:03<13:52,  5.90s/it]
# (train_func pid=487477)
#  14%|█▍        | 23/163 [02:09<13:52,  5.95s/it]
# (train_func pid=487477)
#  15%|█▍        | 24/163 [02:15<13:43,  5.92s/it]
# (train_func pid=487477)
#  15%|█▌        | 25/163 [02:21<13:35,  5.91s/it]
# (train_func pid=487477)
#  16%|█▌        | 26/163 [02:27<13:29,  5.91s/it]
# (train_func pid=487477)
#  17%|█▋        | 27/163 [02:33<13:18,  5.87s/it]
# (train_func pid=487477)
#  17%|█▋        | 28/163 [02:39<13:09,  5.85s/it]
# (train_func pid=487477)
#  18%|█▊        | 29/163 [02:44<13:02,  5.84s/it]
# (train_func pid=487477)
#  18%|█▊        | 30/163 [02:50<12:55,  5.83s/it]
# (train_func pid=487477)
#  19%|█▉        | 31/163 [02:56<12:48,  5.82s/it]
# (train_func pid=487477)
#  20%|█▉        | 32/163 [03:02<12:44,  5.84s/it]
# (train_func pid=487477)
#  20%|██        | 33/163 [03:08<12:38,  5.83s/it]
# (train_func pid=487477)
#  21%|██        | 34/163 [03:14<12:29,  5.81s/it]
# (train_func pid=487477)
#  21%|██▏       | 35/163 [03:19<12:23,  5.81s/it]
# (train_func pid=487477)
#  22%|██▏       | 36/163 [03:25<12:18,  5.82s/it]
# (train_func pid=487477)
#  23%|██▎       | 37/163 [03:31<12:13,  5.82s/it]
# (train_func pid=487477)
#  23%|██▎       | 38/163 [03:37<12:08,  5.83s/it]
# (train_func pid=487477)
#  24%|██▍       | 39/163 [03:43<12:04,  5.84s/it]
# (train_func pid=487477)
#  25%|██▍       | 40/163 [03:49<11:59,  5.85s/it]
# (train_func pid=487477)
#  25%|██▌       | 41/163 [03:54<11:53,  5.85s/it]
# (train_func pid=487477)
#  26%|██▌       | 42/163 [04:00<11:47,  5.84s/it]
# (train_func pid=487477)
#  26%|██▋       | 43/163 [04:06<11:40,  5.84s/it]
# (train_func pid=487477)
#  27%|██▋       | 44/163 [04:12<11:32,  5.82s/it]
# (train_func pid=487477)
#  28%|██▊       | 45/163 [04:18<11:25,  5.81s/it]
# (train_func pid=487477)
#  28%|██▊       | 46/163 [04:23<11:20,  5.82s/it]
# (train_func pid=487477)
#  29%|██▉       | 47/163 [04:29<11:14,  5.82s/it]
# (train_func pid=487477)
#  29%|██▉       | 48/163 [04:35<11:08,  5.81s/it]
# (train_func pid=487477)
#  30%|███       | 49/163 [04:41<11:03,  5.82s/it]
# (train_func pid=487477)
#  31%|███       | 50/163 [04:47<10:56,  5.81s/it]
# (train_func pid=487477)
#  31%|███▏      | 51/163 [04:53<10:54,  5.84s/it]
# (train_func pid=487477)
#  32%|███▏      | 52/163 [04:59<10:57,  5.92s/it]
# (train_func pid=487477)
#  33%|███▎      | 53/163 [05:05<10:55,  5.96s/it]
# (train_func pid=487477)
#  33%|███▎      | 54/163 [05:11<10:58,  6.04s/it]
# (train_func pid=487477)
#  34%|███▎      | 55/163 [05:17<10:48,  6.00s/it]
# (train_func pid=487477)
#  34%|███▍      | 56/163 [05:23<10:42,  6.00s/it]
# (train_func pid=487477)
#  35%|███▍      | 57/163 [05:29<10:42,  6.06s/it]
# (train_func pid=487477)
#  36%|███▌      | 58/163 [05:35<10:27,  5.98s/it]
# (train_func pid=487477)
#  36%|███▌      | 59/163 [05:41<10:19,  5.95s/it]
# (train_func pid=487477)
#  37%|███▋      | 60/163 [05:47<10:08,  5.90s/it]
# (train_func pid=487477)
#  37%|███▋      | 61/163 [05:52<09:58,  5.87s/it]
# (train_func pid=487477)
#  38%|███▊      | 62/163 [05:58<09:49,  5.84s/it]
# (train_func pid=487477)
#  39%|███▊      | 63/163 [06:04<09:42,  5.82s/it]
# (train_func pid=487477)
#  39%|███▉      | 64/163 [06:10<09:37,  5.83s/it]
# (train_func pid=487477)
#  40%|███▉      | 65/163 [06:16<09:29,  5.81s/it]
# (train_func pid=487477)
#  40%|████      | 66/163 [06:21<09:22,  5.80s/it]
# (train_func pid=487477)
#  41%|████      | 67/163 [06:27<09:16,  5.79s/it]
# (train_func pid=487477)
#  42%|████▏     | 68/163 [06:33<09:12,  5.82s/it]
# (train_func pid=487477)
#  42%|████▏     | 69/163 [06:39<09:11,  5.86s/it]
# (train_func pid=487477)
#  43%|████▎     | 70/163 [06:45<09:06,  5.88s/it]
# (train_func pid=487477)
#  44%|████▎     | 71/163 [06:51<09:01,  5.89s/it]
# (train_func pid=487477)
#  44%|████▍     | 72/163 [06:57<08:56,  5.90s/it]
# (train_func pid=487477)
#  45%|████▍     | 73/163 [07:03<08:50,  5.90s/it]
# (train_func pid=487477)
#  45%|████▌     | 74/163 [07:09<08:54,  6.01s/it]
# (train_func pid=487477)
#  46%|████▌     | 75/163 [07:15<08:52,  6.05s/it]
# (train_func pid=487477)
#  47%|████▋     | 76/163 [07:21<08:52,  6.12s/it]
# (train_func pid=487477)
#  47%|████▋     | 77/163 [07:27<08:45,  6.11s/it]
# (train_func pid=487477)
#  48%|████▊     | 78/163 [07:33<08:30,  6.01s/it]
# (train_func pid=487477)
#  48%|████▊     | 79/163 [07:39<08:22,  5.99s/it]
# (train_func pid=487477)
#  49%|████▉     | 80/163 [07:45<08:18,  6.00s/it]
# (train_func pid=487477)
#  50%|████▉     | 81/163 [07:51<08:07,  5.95s/it]
# (train_func pid=487477)
#  50%|█████     | 82/163 [07:57<07:56,  5.89s/it]
# (train_func pid=487477)
#  51%|█████     | 83/163 [08:02<07:47,  5.84s/it]
# (train_func pid=487477)
#  52%|█████▏    | 84/163 [08:08<07:40,  5.83s/it]
# (train_func pid=487477)
#  52%|█████▏    | 85/163 [08:14<07:34,  5.82s/it]
# (train_func pid=487477)
#  53%|█████▎    | 86/163 [08:20<07:27,  5.81s/it]
# ...
#  82%|████████▏ | 133/163 [12:50<02:53,  5.78s/it]
# (train_func pid=487477)
#  82%|████████▏ | 134/163 [12:55<02:47,  5.76s/it]
# (train_func pid=487477)
#  83%|████████▎ | 135/163 [13:01<02:40,  5.75s/it]
# (train_func pid=487477)
#  83%|████████▎ | 136/163 [13:07<02:34,  5.74s/it]
# (train_func pid=487477)
#  84%|████████▍ | 137/163 [13:13<02:30,  5.78s/it]
# (train_func pid=487477)
#  85%|████████▍ | 138/163 [13:18<02:25,  5.81s/it]
# (train_func pid=487477)
#  85%|████████▌ | 139/163 [13:24<02:19,  5.81s/it]
# (train_func pid=487477)
#  86%|████████▌ | 140/163 [13:30<02:13,  5.80s/it]
# (train_func pid=487477)
#  87%|████████▋ | 141/163 [13:36<02:06,  5.77s/it]
# (train_func pid=487477)
#  87%|████████▋ | 142/163 [13:41<02:00,  5.75s/it]
# (train_func pid=487477)
#  88%|████████▊ | 143/163 [13:47<01:54,  5.74s/it]
# (train_func pid=487477)
#  88%|████████▊ | 144/163 [13:53<01:49,  5.76s/it]
# (train_func pid=487477)
#  89%|████████▉ | 145/163 [13:59<01:43,  5.73s/it]
# (train_func pid=487477)
#  90%|████████▉ | 146/163 [14:04<01:37,  5.74s/it]
# (train_func pid=487477)
#  90%|█████████ | 147/163 [14:10<01:31,  5.72s/it]
# (train_func pid=487477)
#  91%|█████████ | 148/163 [14:16<01:25,  5.71s/it]
# (train_func pid=487477)
#  91%|█████████▏| 149/163 [14:21<01:20,  5.72s/it]
# (train_func pid=487477)
#  92%|█████████▏| 150/163 [14:27<01:14,  5.73s/it]
# (train_func pid=487477)
#  93%|█████████▎| 151/163 [14:33<01:08,  5.73s/it]
# (train_func pid=487477)
#  93%|█████████▎| 152/163 [14:39<01:03,  5.73s/it]
# (train_func pid=487477)
#  94%|█████████▍| 153/163 [14:44<00:57,  5.71s/it]
# (train_func pid=487477)
#  94%|█████████▍| 154/163 [14:50<00:51,  5.72s/it]
# (train_func pid=487477)
#  95%|█████████▌| 155/163 [14:56<00:45,  5.74s/it]
# (train_func pid=487477)
#  96%|█████████▌| 156/163 [15:02<00:39,  5.70s/it]
# (train_func pid=487477)
#  96%|█████████▋| 157/163 [15:07<00:34,  5.69s/it]
# (train_func pid=487477)
#  97%|█████████▋| 158/163 [15:13<00:28,  5.68s/it]
# (train_func pid=487477)
#  98%|█████████▊| 159/163 [15:18<00:22,  5.67s/it]
# (train_func pid=487477)
#  98%|█████████▊| 160/163 [15:24<00:16,  5.66s/it]
# (train_func pid=487477)
#  99%|█████████▉| 161/163 [15:30<00:11,  5.67s/it]
# (train_func pid=487477)
#  99%|█████████▉| 162/163 [15:36<00:05,  5.69s/it]
# (train_func pid=487477) {'eval_loss': 0.6111030578613281, 'eval_runtime': 947.186, 'eval_samples_per_second': 2.752, 'eval_steps_per_second': 0.172, 'epoch': 0.02}
# (train_func pid=487477)
#                                                   [A
#  90%|█████████ | 18/20 [3:10:39<18:20, 550.30s/it]
# 100%|██████████| 163/163 [15:41<00:00,  5.59s/it]
#
# (train_func pid=487477) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/root/ray_results/train_func_2024-05-29_16-03-19/train_func_f74df_00000_0_lr=0.0001_2024-05-29_16-03-19/checkpoint_000008)
#  95%|█████████▌| 19/20 [3:13:19<11:57, 717.40s/it]
# (train_func pid=487477) {'loss': 0.828, 'grad_norm': 2.116673231124878, 'learning_rate': 0.0, 'epoch': 0.02}
# 100%|██████████| 20/20 [3:15:52<00:00, 548.07s/it]
# (train_func pid=487477)
#   0%|          | 0/163 [00:00<?, ?it/s]
# (train_func pid=487477)
#   1%|          | 2/163 [00:05<07:48,  2.91s/it]
# (train_func pid=487477)
#   2%|▏         | 3/163 [00:11<11:08,  4.18s/it]
# (train_func pid=487477)
#   2%|▏         | 4/163 [00:17<12:43,  4.80s/it]
# (train_func pid=487477)
#   3%|▎         | 5/163 [00:23<13:32,  5.14s/it]
# (train_func pid=487477)
#   4%|▎         | 6/163 [00:29<14:03,  5.37s/it]
# (train_func pid=487477)
#   4%|▍         | 7/163 [00:35<14:17,  5.50s/it]
# (train_func pid=487477)
#   5%|▍         | 8/163 [00:41<14:36,  5.66s/it]
# (train_func pid=487477)
#   6%|▌         | 9/163 [00:47<14:48,  5.77s/it]
# (train_func pid=487477)
#   6%|▌         | 10/163 [00:52<14:48,  5.81s/it]
# (train_func pid=487477)
#   7%|▋         | 11/163 [00:58<14:43,  5.81s/it]
# (train_func pid=487477)
#   7%|▋         | 12/163 [01:04<14:34,  5.79s/it]
# (train_func pid=487477)
#   8%|▊         | 13/163 [01:10<14:26,  5.78s/it]
# (train_func pid=487477)
#   9%|▊         | 14/163 [01:16<14:20,  5.78s/it]
# (train_func pid=487477)
#   9%|▉         | 15/163 [01:21<14:21,  5.82s/it]
# (train_func pid=487477)
#  10%|▉         | 16/163 [01:27<14:14,  5.81s/it]
# (train_func pid=487477)
#  10%|█         | 17/163 [01:33<14:09,  5.82s/it]
# (train_func pid=487477)
#  11%|█         | 18/163 [01:39<14:02,  5.81s/it]
# (train_func pid=487477)
#  12%|█▏        | 19/163 [01:45<13:53,  5.79s/it]
# (train_func pid=487477)
#  12%|█▏        | 20/163 [01:50<13:44,  5.77s/it]
# (train_func pid=487477)
#  13%|█▎        | 21/163 [01:56<13:41,  5.79s/it]
# (train_func pid=487477)
#  13%|█▎        | 22/163 [02:02<13:41,  5.83s/it]
# (train_func pid=487477)
#  14%|█▍        | 23/163 [02:08<13:33,  5.81s/it]
# (train_func pid=487477)
#  15%|█▍        | 24/163 [02:14<13:28,  5.81s/it]
# (train_func pid=487477)
#  15%|█▌        | 25/163 [02:19<13:20,  5.80s/it]
# (train_func pid=487477)
#  16%|█▌        | 26/163 [02:25<13:17,  5.82s/it]
# (train_func pid=487477)
#  17%|█▋        | 27/163 [02:31<13:09,  5.81s/it]
# (train_func pid=487477)
#  17%|█▋        | 28/163 [02:37<13:07,  5.83s/it]
# (train_func pid=487477)
#  18%|█▊        | 29/163 [02:43<12:59,  5.81s/it]
# (train_func pid=487477)
#  18%|█▊        | 30/163 [02:49<12:56,  5.84s/it]
# (train_func pid=487477)
#  19%|█▉        | 31/163 [02:54<12:49,  5.83s/it]
# (train_func pid=487477)
#  20%|█▉        | 32/163 [03:00<12:42,  5.82s/it]
# (train_func pid=487477)
#  20%|██        | 33/163 [03:06<12:35,  5.81s/it]
# (train_func pid=487477)
#  21%|██        | 34/163 [03:12<12:26,  5.79s/it]
# (train_func pid=487477)
#  21%|██▏       | 35/163 [03:18<12:20,  5.78s/it]
# (train_func pid=487477)
#  22%|██▏       | 36/163 [03:23<12:13,  5.78s/it]
# (train_func pid=487477)
#  23%|██▎       | 37/163 [03:29<12:07,  5.78s/it]
# (train_func pid=487477)
#  23%|██▎       | 38/163 [03:35<12:03,  5.79s/it]
# (train_func pid=487477)
#  24%|██▍       | 39/163 [03:41<11:58,  5.79s/it]
# (train_func pid=487477)
#  25%|██▍       | 40/163 [03:47<11:54,  5.81s/it]
# (train_func pid=487477)
#  25%|██▌       | 41/163 [03:52<11:51,  5.83s/it]
# (train_func pid=487477)
#  26%|██▌       | 42/163 [03:58<11:45,  5.83s/it]
# (train_func pid=487477)
#  26%|██▋       | 43/163 [04:04<11:36,  5.81s/it]
# (train_func pid=487477)
#  27%|██▋       | 44/163 [04:10<11:28,  5.79s/it]
# (train_func pid=487477)
#  28%|██▊       | 45/163 [04:16<11:24,  5.80s/it]
# (train_func pid=487477)
#  28%|██▊       | 46/163 [04:21<11:23,  5.84s/it]
# (train_func pid=487477)
#  29%|██▉       | 47/163 [04:27<11:17,  5.84s/it]
# (train_func pid=487477)
#  29%|██▉       | 48/163 [04:33<11:10,  5.83s/it]
# (train_func pid=487477)
#  30%|███       | 49/163 [04:39<11:04,  5.83s/it]
# (train_func pid=487477)
#  31%|███       | 50/163 [04:45<10:57,  5.82s/it]
# (train_func pid=487477)
#  31%|███▏      | 51/163 [04:51<10:50,  5.81s/it]
# (train_func pid=487477)
#  32%|███▏      | 52/163 [04:56<10:43,  5.80s/it]
# (train_func pid=487477)
#  33%|███▎      | 53/163 [05:02<10:37,  5.79s/it]
# (train_func pid=487477)
#  33%|███▎      | 54/163 [05:08<10:32,  5.80s/it]
# (train_func pid=487477)
#  34%|███▎      | 55/163 [05:14<10:26,  5.80s/it]
# (train_func pid=487477)
#  34%|███▍      | 56/163 [05:20<10:21,  5.80s/it]
# (train_func pid=487477)
#  35%|███▍      | 57/163 [05:25<10:16,  5.82s/it]
# (train_func pid=487477)
#  36%|███▌      | 58/163 [05:31<10:11,  5.82s/it]
# (train_func pid=487477)
#  36%|███▌      | 59/163 [05:37<10:11,  5.88s/it]
# (train_func pid=487477)
#  37%|███▋      | 60/163 [05:43<10:05,  5.88s/it]
# (train_func pid=487477)
#  37%|███▋      | 61/163 [05:49<09:55,  5.84s/it]
# (train_func pid=487477)
#  38%|███▊      | 62/163 [05:55<09:48,  5.83s/it]
# (train_func pid=487477)
#  39%|███▊      | 63/163 [06:01<09:44,  5.84s/it]
# (train_func pid=487477)
#  39%|███▉      | 64/163 [06:06<09:37,  5.83s/it]
# (train_func pid=487477)
#  40%|███▉      | 65/163 [06:12<09:29,  5.82s/it]
# (train_func pid=487477)
#  40%|████      | 66/163 [06:18<09:21,  5.79s/it]
# (train_func pid=487477)
#  41%|████      | 67/163 [06:24<09:18,  5.81s/it]
# (train_func pid=487477)
#  42%|████▏     | 68/163 [06:30<09:12,  5.82s/it]
# (train_func pid=487477)
#  42%|████▏     | 69/163 [06:35<09:05,  5.81s/it]
# (train_func pid=487477)
#  43%|████▎     | 70/163 [06:41<08:59,  5.80s/it]
# (train_func pid=487477)
#  44%|████▎     | 71/163 [06:47<08:52,  5.79s/it]
# (train_func pid=487477)
#  44%|████▍     | 72/163 [06:53<08:46,  5.79s/it]
# (train_func pid=487477)
#  45%|████▍     | 73/163 [06:58<08:42,  5.80s/it]
# (train_func pid=487477)
#  45%|████▌     | 74/163 [07:04<08:34,  5.78s/it]
# (train_func pid=487477)
#  46%|████▌     | 75/163 [07:10<08:28,  5.78s/it]
# (train_func pid=487477)
#  47%|████▋     | 76/163 [07:16<08:24,  5.80s/it]
# (train_func pid=487477)
#  47%|████▋     | 77/163 [07:22<08:17,  5.79s/it]
# (train_func pid=487477)
#  48%|████▊     | 78/163 [07:27<08:11,  5.79s/it]
# (train_func pid=487477)
#  48%|████▊     | 79/163 [07:33<08:05,  5.78s/it]
# (train_func pid=487477)
#  49%|████▉     | 80/163 [07:39<08:00,  5.79s/it]
# (train_func pid=487477)
#  50%|████▉     | 81/163 [07:45<07:54,  5.79s/it]
# (train_func pid=487477)
#  50%|█████     | 82/163 [07:51<07:48,  5.78s/it]
# (train_func pid=487477)
#  51%|█████     | 83/163 [07:56<07:43,  5.79s/it]
# (train_func pid=487477)
#  52%|█████▏    | 84/163 [08:02<07:39,  5.81s/it]
# (train_func pid=487477)
#  52%|█████▏    | 85/163 [08:08<07:35,  5.84s/it]
# (train_func pid=487477)
#  53%|█████▎    | 86/163 [08:14<07:28,  5.82s/it]
# (train_func pid=487477)
#  53%|█████▎    | 87/163 [08:20<07:21,  5.81s/it]
# (train_func pid=487477)
#  54%|█████▍    | 88/163 [08:25<07:15,  5.80s/it]
# (train_func pid=487477)
#  55%|█████▍    | 89/163 [08:31<07:09,  5.81s/it]
# (train_func pid=487477)
#  55%|█████▌    | 90/163 [08:37<07:06,  5.84s/it]
# (train_func pid=487477)
#  56%|█████▌    | 91/163 [08:43<07:00,  5.84s/it]
# (train_func pid=487477)
#  56%|█████▋    | 92/163 [08:49<06:53,  5.82s/it]
# (train_func pid=487477)
#  57%|█████▋    | 93/163 [08:55<06:50,  5.86s/it]
# (train_func pid=487477)
#  58%|█████▊    | 94/163 [09:01<06:45,  5.87s/it]
# (train_func pid=487477)
#  58%|█████▊    | 95/163 [09:07<06:42,  5.92s/it]
# (train_func pid=487477)
#  59%|█████▉    | 96/163 [09:13<06:38,  5.95s/it]
# (train_func pid=487477)
#  60%|█████▉    | 97/163 [09:19<06:29,  5.91s/it]
# (train_func pid=487477)
#  60%|██████    | 98/163 [09:24<06:21,  5.87s/it]
# (train_func pid=487477)
#  61%|██████    | 99/163 [09:30<06:14,  5.85s/it]
# (train_func pid=487477)
#  61%|██████▏   | 100/163 [09:36<06:07,  5.84s/it]
# (train_func pid=487477)
#  62%|██████▏   | 101/163 [09:42<06:01,  5.83s/it]
# (train_func pid=487477)
#  63%|██████▎   | 102/163 [09:48<05:55,  5.82s/it]
# (train_func pid=487477)
#  63%|██████▎   | 103/163 [09:53<05:48,  5.81s/it]
# (train_func pid=487477)
#  64%|██████▍   | 104/163 [09:59<05:41,  5.78s/it]
# (train_func pid=487477)
#  64%|██████▍   | 105/163 [10:05<05:36,  5.80s/it]
# (train_func pid=487477)
#  65%|██████▌   | 106/163 [10:11<05:33,  5.85s/it]
# (train_func pid=487477)
#  66%|██████▌   | 107/163 [10:17<05:27,  5.84s/it]
# (train_func pid=487477)
#  66%|██████▋   | 108/163 [10:22<05:19,  5.81s/it]
# (train_func pid=487477)
#  67%|██████▋   | 109/163 [10:28<05:13,  5.81s/it]
# (train_func pid=487477)
#  67%|██████▋   | 110/163 [10:34<05:08,  5.82s/it]
# (train_func pid=487477)
#  68%|██████▊   | 111/163 [10:40<05:05,  5.87s/it]
# (train_func pid=487477)
#  69%|██████▊   | 112/163 [10:46<04:57,  5.84s/it]
# (train_func pid=487477)
#  69%|██████▉   | 113/163 [10:52<04:51,  5.82s/it]
# (train_func pid=487477)
#  70%|██████▉   | 114/163 [10:57<04:44,  5.81s/it]
# (train_func pid=487477)
#  71%|███████   | 115/163 [11:03<04:38,  5.80s/it]
# (train_func pid=487477)
#  71%|███████   | 116/163 [11:09<04:31,  5.78s/it]
# (train_func pid=487477)
#  72%|███████▏  | 117/163 [11:15<04:27,  5.82s/it]
# (train_func pid=487477)
#  72%|███████▏  | 118/163 [11:21<04:22,  5.83s/it]
# (train_func pid=487477)
#  73%|███████▎  | 119/163 [11:27<04:17,  5.86s/it]
# (train_func pid=487477)
#  74%|███████▎  | 120/163 [11:32<04:11,  5.85s/it]
# (train_func pid=487477)
#  74%|███████▍  | 121/163 [11:38<04:04,  5.83s/it]
# (train_func pid=487477)
#  75%|███████▍  | 122/163 [11:44<03:58,  5.82s/it]
# (train_func pid=487477)
#  75%|███████▌  | 123/163 [11:50<03:52,  5.82s/it]
# (train_func pid=487477)
#  76%|███████▌  | 124/163 [11:56<03:49,  5.89s/it]
# (train_func pid=487477)
#  77%|███████▋  | 125/163 [12:02<03:43,  5.87s/it]
# (train_func pid=487477)
#  77%|███████▋  | 126/163 [12:07<03:36,  5.85s/it]
# (train_func pid=487477)
#  78%|███████▊  | 127/163 [12:13<03:31,  5.87s/it]
# (train_func pid=487477)
#  79%|███████▊  | 128/163 [12:19<03:26,  5.89s/it]
# (train_func pid=487477)
#  79%|███████▉  | 129/163 [12:25<03:19,  5.86s/it]
# (train_func pid=487477)
#  80%|███████▉  | 130/163 [12:31<03:12,  5.84s/it]
# (train_func pid=487477)
#  80%|████████  | 131/163 [12:37<03:08,  5.88s/it]
# (train_func pid=487477)
#  81%|████████  | 132/163 [12:43<03:03,  5.90s/it]
# (train_func pid=487477)
#  82%|████████▏ | 133/163 [12:49<02:57,  5.91s/it]
# (train_func pid=487477)
#  82%|████████▏ | 134/163 [12:55<02:50,  5.88s/it]
# (train_func pid=487477)
#  83%|████████▎ | 135/163 [13:00<02:43,  5.85s/it]
# (train_func pid=487477)
#  83%|████████▎ | 136/163 [13:06<02:38,  5.88s/it]
# (train_func pid=487477)
#  84%|████████▍ | 137/163 [13:12<02:32,  5.86s/it]
# (train_func pid=487477)
#  85%|████████▍ | 138/163 [13:18<02:27,  5.90s/it]
# (train_func pid=487477)
#  85%|████████▌ | 139/163 [13:24<02:21,  5.91s/it]
# (train_func pid=487477)
#  86%|████████▌ | 140/163 [13:30<02:16,  5.92s/it]
# (train_func pid=487477)
#  87%|████████▋ | 141/163 [13:36<02:09,  5.89s/it]
# (train_func pid=487477)
#  87%|████████▋ | 142/163 [13:42<02:03,  5.86s/it]
# (train_func pid=487477)
#  88%|████████▊ | 143/163 [13:47<01:56,  5.85s/it]
# (train_func pid=487477)
#  88%|████████▊ | 144/163 [13:53<01:50,  5.82s/it]
# (train_func pid=487477)
#  89%|████████▉ | 145/163 [13:59<01:45,  5.83s/it]
# (train_func pid=487477)
#  90%|████████▉ | 146/163 [14:05<01:39,  5.83s/it]
# (train_func pid=487477)
#  90%|█████████ | 147/163 [14:11<01:32,  5.80s/it]
# (train_func pid=487477)
#  91%|█████████ | 148/163 [14:16<01:27,  5.81s/it]
# (train_func pid=487477)
#  91%|█████████▏| 149/163 [14:22<01:21,  5.80s/it]
# (train_func pid=487477)
#  92%|█████████▏| 150/163 [14:28<01:15,  5.80s/it]
# (train_func pid=487477)
#  93%|█████████▎| 151/163 [14:34<01:09,  5.81s/it]
# (train_func pid=487477)
#  93%|█████████▎| 152/163 [14:40<01:03,  5.81s/it]
# (train_func pid=487477)
#  94%|█████████▍| 153/163 [14:45<00:57,  5.79s/it]
# (train_func pid=487477)
#  94%|█████████▍| 154/163 [14:51<00:52,  5.78s/it]
# (train_func pid=487477)
#  95%|█████████▌| 155/163 [14:57<00:46,  5.82s/it]
# (train_func pid=487477)
#  96%|█████████▌| 156/163 [15:03<00:41,  5.89s/it]
# (train_func pid=487477)
#  96%|█████████▋| 157/163 [15:09<00:35,  5.86s/it]
# (train_func pid=487477)
#  97%|█████████▋| 158/163 [15:15<00:29,  5.86s/it]
# (train_func pid=487477)
#  98%|█████████▊| 159/163 [15:21<00:23,  5.88s/it]
# (train_func pid=487477)
#  98%|█████████▊| 160/163 [15:26<00:17,  5.85s/it]
# (train_func pid=487477)
#  99%|█████████▉| 161/163 [15:32<00:11,  5.85s/it]
# (train_func pid=487477)
#  99%|█████████▉| 162/163 [15:38<00:05,  5.84s/it]
# (train_func pid=487477) {'eval_loss': 0.6069474220275879, 'eval_runtime': 949.8699, 'eval_samples_per_second': 2.745, 'eval_steps_per_second': 0.172, 'epoch': 0.02}
# (train_func pid=487477)
#                                                   [A
# 100%|██████████| 20/20 [3:31:42<00:00, 548.07s/it]
# 100%|██████████| 163/163 [15:44<00:00,  5.72s/it]
#
# (train_func pid=487477) Checkpoint successfully created at: Checkpoint(filesystem=local, path=/root/ray_results/train_func_2024-05-29_16-03-19/train_func_f74df_00000_0_lr=0.0001_2024-05-29_16-03-19/checkpoint_000009)
# 2024-05-29 19:35:09,807	INFO tune.py:1007 -- Wrote the latest version of all result files and experiment state to '/root/ray_results/train_func_2024-05-29_16-03-19' in 0.0032s.
# 2024-05-29 19:35:09,811	INFO tune.py:1039 -- Total run time: 12710.70 seconds (12710.69 seconds for the tuning loop).

# %%
print("Best config is:", results.get_best_result().config)
# Out:
# (train_func pid=487477) {'train_runtime': 12705.7604, 'train_samples_per_second': 0.201, 'train_steps_per_second': 0.002, 'train_loss': 0.9348451197147369, 'epoch': 0.02}Best config is: {'lr': 0.0001}
# 100%|██████████| 20/20 [3:31:45<00:00, 635.29s/it]
